# %%
import importlib
import numpy as np 
import matplotlib.pyplot as plt 
import functions

# %%
importlib.reload(functions)
# Out:
# <module 'functions' from '/mnt/d/Skoltech/NLA/Project/NLA_Final_Project/functions.py'>

# %%
N = 12
coords, dists = functions.create_graph(N)

# %%
functions.plot_graph(coords)

# %%
functions.LP_TSP_solve(coords, dists)
# Out:
# [0, 2, 3, 1, 8, 6, 4, 11, 10, 7, 9, 5]
